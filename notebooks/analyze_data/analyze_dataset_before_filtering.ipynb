# %% [markdown]
# # Analyze the created dataset before pre-processing
# This notebook analyzes each feature of the dataset and is leveraged to understand which type of paintings are under-represented.

# %% [markdown]
# ### 0. Import libraries and load data

# %%
import polars as pl
import plotly.express as px

INTERMEDIATE_DATA_PATH = "../../data/intermediate/"
COLORS = ["#cd968e", "#acb0e0", "#aecbdc", "#bcd5c3", "#bfbfbf"]

# %%
datasets_names = ["met", "wikiart", "wga"]
datasets = []

for dataset_name in datasets_names:
    datasets.append(
        pl.read_json(
            f"{INTERMEDIATE_DATA_PATH}{dataset_name}_paintings/{dataset_name}_paintings_enhanced_data.json"
        ).with_columns(pl.lit(dataset_name).alias("source"))
    )

data = pl.concat(datasets)
data
# Out:
# shape: (18_490, 9)
# ┌───────┬──────────────┬─────────────┬──────┬───┬─────────────┬─────────────┬─────────────┬────────┐
# │ id    ┆ title        ┆ artist      ┆ year ┆ … ┆ fine_graine ┆ style       ┆ description ┆ source │
# │ ---   ┆ ---          ┆ ---         ┆ ---  ┆   ┆ d_type      ┆ ---         ┆ ---         ┆ ---    │
# │ i64   ┆ str          ┆ str         ┆ i64  ┆   ┆ ---         ┆ str         ┆ str         ┆ str    │
# │       ┆              ┆             ┆      ┆   ┆ str         ┆             ┆             ┆        │
# ╞═══════╪══════════════╪═════════════╪══════╪═══╪═════════════╪═════════════╪═════════════╪════════╡
# │ 0     ┆ A Ship in a  ┆ Ivan Konsta ┆ 1900 ┆ … ┆ marina      ┆ romanticism ┆ Aivazovsky  ┆ met    │
# │       ┆ Stormy Sea   ┆ ntinovich   ┆      ┆   ┆             ┆             ┆ was a       ┆        │
# │       ┆              ┆ Aivazovsk…  ┆      ┆   ┆             ┆             ┆ celebrated  ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ pa…         ┆        │
# │ 1     ┆ Saint Giles  ┆ Miguel      ┆ 1413 ┆ … ┆ null        ┆ null        ┆ These       ┆ met    │
# │       ┆ with Christ  ┆ Alcañiz (or ┆      ┆   ┆             ┆             ┆ panels,     ┆        │
# │       ┆ Triump…      ┆ Miquel      ┆      ┆   ┆             ┆             ┆ from an     ┆        │
# │       ┆              ┆ Alca…       ┆      ┆   ┆             ┆             ┆ altarpie…   ┆        │
# │ 2     ┆ Flora and    ┆ Jacopo      ┆ 1739 ┆ … ┆ null        ┆ null        ┆ The         ┆ met    │
# │       ┆ Zephyr       ┆ Amigoni     ┆      ┆   ┆             ┆             ┆ composition ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ celebrates  ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ the…        ┆        │
# │ 3     ┆ Jérôme       ┆ Giacomo     ┆ 1813 ┆ … ┆ null        ┆ null        ┆ The         ┆ met    │
# │       ┆ Bonaparte    ┆ Andreoli    ┆      ┆   ┆             ┆             ┆ following   ┆        │
# │       ┆ (1784–1860), ┆             ┆      ┆   ┆             ┆             ┆ miniature   ┆        │
# │       ┆ …            ┆             ┆      ┆   ┆             ┆             ┆ is cle…     ┆        │
# │ 4     ┆ Saint        ┆ Fra         ┆ 1430 ┆ … ┆ null        ┆ null        ┆ This early  ┆ met    │
# │       ┆ Alexander    ┆ Angelico    ┆      ┆   ┆             ┆             ┆ work by Fra ┆        │
# │       ┆              ┆ (Guido di   ┆      ┆   ┆             ┆             ┆ Angelic…    ┆        │
# │       ┆              ┆ Pietro)     ┆      ┆   ┆             ┆             ┆             ┆        │
# │ …     ┆ …            ┆ …           ┆ …    ┆ … ┆ …           ┆ …           ┆ …           ┆ …      │
# │ 18485 ┆ Creation of  ┆ MICHELANGEL ┆ 1510 ┆ … ┆ religious   ┆ high        ┆ The fourth  ┆ wga    │
# │       ┆ Adam         ┆ O           ┆      ┆   ┆ painting    ┆ renaissance ┆ scene in    ┆        │
# │       ┆              ┆ Buonarroti  ┆      ┆   ┆             ┆             ┆ the chrono… ┆        │
# │ 18486 ┆ Herdsmen and ┆ BERCHEM,    ┆ 1665 ┆ … ┆ null        ┆ null        ┆ The         ┆ wga    │
# │       ┆ Herds at a   ┆ Nicolaes    ┆      ┆   ┆             ┆             ┆ landscape   ┆        │
# │       ┆ Waterf…      ┆             ┆      ┆   ┆             ┆             ┆ Herdsmen    ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ and Her…    ┆        │
# │ 18487 ┆ The Madonna  ┆ RAFFAELLO   ┆ 1511 ┆ … ┆ null        ┆ null        ┆ The         ┆ wga    │
# │       ┆ of Foligno   ┆ Sanzio      ┆      ┆   ┆             ┆             ┆ painting    ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ was         ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ executed    ┆        │
# │       ┆              ┆             ┆      ┆   ┆             ┆             ┆ for …       ┆        │
# │ 18488 ┆ The Second   ┆ GOYA Y      ┆ 1814 ┆ … ┆ battle      ┆ romanticism ┆ After the   ┆ wga    │
# │       ┆ of May,      ┆ LUCIENTES,  ┆      ┆   ┆ painting    ┆             ┆ expulsion   ┆        │
# │       ┆ 1808: The C… ┆ Francisco   ┆      ┆   ┆             ┆             ┆ of the Nap… ┆        │
# │       ┆              ┆ de          ┆      ┆   ┆             ┆             ┆             ┆        │
# │ 18489 ┆ Blossoming   ┆ GOGH,       ┆ 1888 ┆ … ┆ flower      ┆ post-impres ┆ Catalogue   ┆ wga    │
# │       ┆ Almond       ┆ Vincent van ┆      ┆   ┆ painting    ┆ sionism     ┆ numbers: F  ┆        │
# │       ┆ Branch in a  ┆             ┆      ┆   ┆             ┆             ┆ 392, JH 1…  ┆        │
# │       ┆ …            ┆             ┆      ┆   ┆             ┆             ┆             ┆        │
# └───────┴──────────────┴─────────────┴──────┴───┴─────────────┴─────────────┴─────────────┴────────┘

# %%
data["source"].value_counts().sort("count")
# Out:
# shape: (3, 2)
# ┌─────────┬───────┐
# │ source  ┆ count │
# │ ---     ┆ ---   │
# │ str     ┆ u32   │
# ╞═════════╪═══════╡
# │ wikiart ┆ 1304  │
# │ met     ┆ 2011  │
# │ wga     ┆ 15175 │
# └─────────┴───────┘

# %% [markdown]
# ### 1. Artists

# %%
artist_frequency = data["artist"].value_counts().sort("count").rename({"count": "frequency"})
print(f"Number of artists: {len(set(data['artist'].to_list()))}")

fig = px.histogram(
    artist_frequency, x="frequency", title="Artist Frequency", color_discrete_sequence=COLORS[2:3]
)
fig.show()
# Out:
# Number of artists: 3799

# %%
data["artist"].value_counts().sort("count")
# Out:
# shape: (3_799, 2)
# ┌──────────────────────────┬───────┐
# │ artist                   ┆ count │
# │ ---                      ┆ ---   │
# │ str                      ┆ u32   │
# ╞══════════════════════════╪═══════╡
# │ Barent Fabritius         ┆ 1     │
# │ KNEBEL, Franz            ┆ 1     │
# │ Berlinghiero             ┆ 1     │
# │ VOSMAER, Jacob Woutersz  ┆ 1     │
# │ COUSIN, Jean the Younger ┆ 1     │
# │ …                        ┆ …     │
# │ VERONESE, Paolo          ┆ 170   │
# │ TIZIANO Vecellio         ┆ 172   │
# │ TINTORETTO               ┆ 172   │
# │ MICHELANGELO Buonarroti  ┆ 175   │
# │ RAFFAELLO Sanzio         ┆ 201   │
# └──────────────────────────┴───────┘

# %%
paintings_with_type_or_style = data.filter(
    pl.col("coarse_type").is_not_null()
    | pl.col("fine_grained_type").is_not_null()
    | pl.col("style").is_not_null()
)

artists_with_type_or_style = len(set(paintings_with_type_or_style["artist"].to_list()))
print(f"Artists that have paintings with associated style or type: {artists_with_type_or_style}")
# Out:
# Artists that have paintings with associated style or type: 3202

# %% [markdown]
# ### 2. Year of creation

# %%
paintings_per_century = (
    data.with_columns((pl.col("year") // 100 + 1).alias("century"))
    .group_by("century", "source")
    .len()
    .sort("century")
    .with_columns(pl.col("len") / data.shape[0] * 100)
    .rename({"len": "percentage"})
)
print(f"Covered period: {data['year'].min()} - {data['year'].max()}")

fig = px.bar(
    paintings_per_century,
    x="century",
    y="percentage",
    color="source",
    title="Distribution of Paintings Across Centuries",
    color_discrete_sequence=COLORS[:4],
)
fig.update_layout(xaxis={"dtick": 1})
fig.show()
# Out:
# Covered period: 1007 - 2022

# %%
paintings_per_century_no = (
    data.with_columns((pl.col("year") // 100 + 1).alias("century"))
    .group_by("century", "source")
    .len()
    .sort("century")
    .rename({"len": "paintings number"})
)

with pl.Config(tbl_rows=30):
    display(paintings_per_century_no)
# Out:
# shape: (29, 3)
# ┌─────────┬─────────┬──────────────────┐
# │ century ┆ source  ┆ paintings number │
# │ ---     ┆ ---     ┆ ---              │
# │ i64     ┆ str     ┆ u32              │
# ╞═════════╪═════════╪══════════════════╡
# │ 11      ┆ wikiart ┆ 2                │
# │ 11      ┆ wga     ┆ 14               │
# │ 12      ┆ wikiart ┆ 1                │
# │ 12      ┆ wga     ┆ 44               │
# │ 13      ┆ wga     ┆ 115              │
# │ 13      ┆ wikiart ┆ 21               │
# │ 13      ┆ met     ┆ 4                │
# │ 14      ┆ wga     ┆ 970              │
# │ 14      ┆ met     ┆ 55               │
# │ 14      ┆ wikiart ┆ 6                │
# │ 15      ┆ met     ┆ 176              │
# │ 15      ┆ wikiart ┆ 28               │
# │ 15      ┆ wga     ┆ 2600             │
# │ 16      ┆ met     ┆ 256              │
# │ 16      ┆ wga     ┆ 3624             │
# │ 16      ┆ wikiart ┆ 104              │
# │ 17      ┆ wga     ┆ 3975             │
# │ 17      ┆ wikiart ┆ 85               │
# │ 17      ┆ met     ┆ 414              │
# │ 18      ┆ wikiart ┆ 85               │
# │ 18      ┆ wga     ┆ 1799             │
# │ 18      ┆ met     ┆ 406              │
# │ 19      ┆ wikiart ┆ 389              │
# │ 19      ┆ wga     ┆ 1825             │
# │ 19      ┆ met     ┆ 670              │
# │ 20      ┆ wikiart ┆ 504              │
# │ 20      ┆ met     ┆ 30               │
# │ 20      ┆ wga     ┆ 209              │
# │ 21      ┆ wikiart ┆ 79               │
# └─────────┴─────────┴──────────────────┘

# %% [markdown]
# ### 3. Type and style

# %%
paintings_with_type_and_style = data.filter(
    pl.col("coarse_type").is_not_null()
    & pl.col("fine_grained_type").is_not_null()
    & pl.col("style").is_not_null()
)
print(f"Paintings with style and type: {paintings_with_type_and_style.shape[0]}")
print(f"Paintings with style or type: {paintings_with_type_or_style.shape[0]}")
# Out:
# Paintings with style and type: 5307
# Paintings with style or type: 17234

# %%
print(
    f"Number of painintgs with coarse type: {data.filter(pl.col('coarse_type').is_not_null()).shape[0]}"
)
coarse_grained_types = data["coarse_type"].value_counts().sort("count").to_numpy()
print(f"The {len(coarse_grained_types)} coarse types are:\n{coarse_grained_types}")
# Out:
# Number of painintgs with coarse type: 15842
# The 10 coarse types are:
# [['sketch and study' 40]
#  ['interior' 401]
#  ['still life' 514]
#  ['history' 571]
#  ['genre' 1301]
#  ['landscape' 1684]
#  ['mythological' 1776]
#  [None 2648]
#  ['portrait' 2668]
#  ['religious' 6887]]

# %%
print(
    f"Number of paintings with fine-grained type: {data.filter(pl.col('fine_grained_type').is_not_null()).shape[0]}"
)
fine_grained_types = data["fine_grained_type"].value_counts().sort("count").to_numpy()
print(f"The {len(fine_grained_types)} fine-grained types are:\n{fine_grained_types}")
# Out:
# Number of paintings with fine-grained type: 6711
# The 146 fine-grained types are:
# [['veduta, genre painting' 1]
#  ['religious painting, flower painting' 1]
#  ['literary painting, portrait' 1]
#  ['genre painting, history painting' 1]
#  ['cloudscape' 1]
#  ['literary painting, battle painting' 1]
#  ['landscape, history painting' 1]
#  ['mythological painting, literary painting' 1]
#  ['allegorical painting, symbolic painting' 1]
#  ['animal painting, still life' 1]
#  ['portrait, nude painting (nu)' 1]
#  ['genre painting, portrait' 1]
#  ['self-portrait, religious painting' 1]
#  ['cloudscape, flower painting' 1]
#  ['nude painting (nu), sketch and study' 1]
#  ['symbolic painting, figurative' 1]
#  ['landscape, nude painting (nu)' 1]
#  ['religious painting, symbolic painting' 1]
#  ['figurative, nude painting (nu)' 1]
#  ['landscape, pastorale' 1]
#  ['vanitas' 1]
#  ['genre painting, wildlife painting' 1]
#  ['battle painting, landscape' 1]
#  ['cloudscape, sketch and study' 1]
#  ['genre painting, religious painting' 1]
#  ['sketch and study, history painting' 1]
#  ['portrait, allegorical painting' 1]
#  ['animal painting, genre painting' 1]
#  ['still life, animal painting' 1]
#  ['icon' 1]
#  ['nude painting (nu), literary painting' 1]
#  ['symbolic painting, genre painting' 1]
#  ["trompe-l'œil, interior" 1]
#  ['flower painting, landscape' 1]
#  ['landscape, capriccio' 1]
#  ['mythological painting, religious painting' 1]
#  ['landscape, veduta' 1]
#  ['genre painting, cloudscape' 1]
#  ['genre painting, self-portrait' 1]
#  ["interior, trompe-l'œil" 1]
#  ['portrait, vanitas' 1]
#  ['marina, landscape' 1]
#  ['religious painting, cityscape' 1]
#  ['animal painting, caricature' 1]
#  ['religious painting, history painting' 1]
#  ['nude painting (nu), religious painting' 1]
#  ['landscape, portrait' 1]
#  ['symbolic painting, design' 1]
#  ['self-portrait, vanitas' 1]
#  ['figurative, religious painting' 1]
#  ['landscape, marina' 1]
#  ['cityscape, religious painting' 1]
#  ['landscape, battle painting' 1]
#  ['nude painting (nu), self-portrait' 1]
#  ['design, religious painting' 1]
#  ['poster' 1]
#  ['yakusha-e' 1]
#  ['cityscape, allegorical painting' 1]
#  ['landscape, cityscape' 1]
#  ['religious painting, allegorical painting' 1]
#  ['literary painting, nude painting (nu)' 1]
#  ["still life, trompe-l'œil" 2]
#  ['landscape, flower painting' 2]
#  ['religious painting, tronie' 2]
#  ['history painting, landscape' 2]
#  ['cloudscape, landscape' 2]
#  ['battle painting, history painting' 2]
#  ["landscape, trompe-l'œil" 2]
#  ['landscape, architecture' 2]
#  ['self-portrait, portrait' 2]
#  ['landscape, figurative' 2]
#  ['genre painting, cityscape' 2]
#  ['figurative, genre painting' 2]
#  ['landscape, genre painting' 2]
#  ['interior, genre painting' 2]
#  ['cityscape, veduta' 2]
#  ['symbolic painting, self-portrait' 2]
#  ['symbolic painting, religious painting' 2]
#  ['marina, battle painting' 2]
#  ['panorama, landscape' 2]
#  ['genre painting, allegorical painting' 2]
#  ['allegorical painting, mythological painting' 2]
#  ['quadratura, mythological painting' 2]
#  ["genre painting, trompe-l'œil" 2]
#  ['history painting, symbolic painting' 2]
#  ['cloudscape, marina' 2]
#  ['mythological painting, nude painting (nu)' 2]
#  ['religious painting, portrait' 2]
#  ['marina, cloudscape' 2]
#  ["portrait, trompe-l'œil" 2]
#  ['flower painting, animal painting' 2]
#  ['genre painting, interior' 3]
#  ['cityscape, portrait' 3]
#  ['history painting, genre painting' 3]
#  ['landscape, literary painting' 3]
#  ['religious painting, cloudscape' 3]
#  ['history painting, battle painting' 3]
#  ['landscape, cloudscape' 3]
#  ['portrait, symbolic painting' 3]
#  ['portrait, sketch and study' 3]
#  ['panorama' 3]
#  ['wildlife painting' 3]
#  ['nude painting (nu), portrait' 3]
#  ['religious painting, nude painting (nu)' 3]
#  ['genre painting, nude painting (nu)' 3]
#  ["allegorical painting, trompe-l'œil" 4]
#  ['portrait, self-portrait' 4]
#  ['landscape, religious painting' 4]
#  ['caricature' 4]
#  ['genre painting, landscape' 4]
#  ['figurative, symbolic painting' 4]
#  ['illustration' 5]
#  ['cityscape, landscape' 5]
#  ['portrait, genre painting' 5]
#  ["mythological painting, trompe-l'œil" 5]
#  ['self-portrait, tronie' 5]
#  ['genre painting, tronie' 6]
#  ["religious painting, trompe-l'œil" 6]
#  ['religious painting, landscape' 8]
#  ['quadratura' 8]
#  ['pastorale' 13]
#  ['capriccio' 15]
#  ['design' 17]
#  ['sculpture' 20]
#  ['portrait, tronie' 22]
#  ['battle painting' 23]
#  ['interior' 35]
#  ['animal painting' 39]
#  ['flower painting' 40]
#  ['literary painting' 48]
#  ['marina' 52]
#  ['symbolic painting' 62]
#  ['veduta' 68]
#  ['nude painting (nu)' 79]
#  ['still life' 100]
#  ['sketch and study' 102]
#  ['self-portrait' 111]
#  ['history painting' 119]
#  ['cityscape' 165]
#  ['allegorical painting' 202]
#  ['mythological painting' 331]
#  ['landscape' 445]
#  ['genre painting' 853]
#  ['portrait' 1015]
#  ['religious painting' 2495]
#  [None 11779]]

# %%
print(f"Number of painintgs with style: {data.filter(pl.col('style').is_not_null()).shape[0]}")
styles = data["style"].value_counts().sort("count").to_numpy()
print(f"The {len(styles)} styles are:\n{styles}")
# Out:
# Number of painintgs with style: 6722
# The 156 styles are:
# [['baroque, romanticism' 1]
#  ['impressionism, japonism' 1]
#  ['art nouveau (modern), romanticism' 1]
#  ['international gothic, northern renaissance' 1]
#  ['surrealism, feminist art' 1]
#  ['hyper-realism' 1]
#  ['intimism' 1]
#  ['expressionism, social realism' 1]
#  ['impressionism, figurative expressionism' 1]
#  ['symbolism, orientalism' 1]
#  ['romanticism, naïve art (primitivism)' 1]
#  ['expressionism, muralism' 1]
#  ['regionalism, social realism' 1]
#  ['romanticism, symbolism' 1]
#  ['baroque, classicism' 1]
#  ['late byzantine/palaeologan renaissance (c. 1261–1453), macedonian renaissance (867–1056)'
#   1]
#  ['realism, surrealism' 1]
#  ['op art' 1]
#  ['realism, symbolism' 1]
#  ['luminism, romanticism' 1]
#  ['biedermeier, romanticism' 1]
#  ['purism' 1]
#  ['romanticism, naturalism' 1]
#  ['post-impressionism, symbolism' 1]
#  ['mannerism (late renaissance), high renaissance' 1]
#  ['art nouveau (modern), impressionism' 1]
#  ['romanticism, neoclassicism' 1]
#  ['new kingdom' 1]
#  ['romanticism, ink and wash painting' 1]
#  ['magic realism, social realism' 1]
#  ['art brut' 1]
#  ['synthetism, cloisonnism' 1]
#  ['socialist realism' 1]
#  ['contemporary realism, regionalism' 1]
#  ['synthetism' 1]
#  ['expressionism, cubo-expressionism' 1]
#  ['contemporary realism, neo-baroque' 1]
#  ['contemporary realism, kitsch' 1]
#  ['impressionism, post-impressionism' 1]
#  ['early christian' 1]
#  ['naïve art (primitivism), post-impressionism' 1]
#  ['middle byzantine (c. 850–1204), novgorod school of icon painting' 1]
#  ['mughal' 1]
#  ['divisionism, social realism' 1]
#  ['neo-suprematism' 1]
#  ['lowbrow art, surrealism' 1]
#  ['neo-impressionism, pointillism' 1]
#  ['modernism' 1]
#  ['muralism, social realism' 1]
#  ['impressionism, symbolism' 1]
#  ['expressionism, surrealism' 1]
#  ['academicism, neoclassicism' 1]
#  ['photorealism' 1]
#  ['kanō school style' 1]
#  ['classicism, baroque' 1]
#  ['divisionism' 1]
#  ['social realism, divisionism' 1]
#  ['symbolism, synthetism' 1]
#  ['divisionism, impressionism' 1]
#  ['feminist art' 1]
#  ['rococo, baroque' 1]
#  ['rococo, neoclassicism' 1]
#  ['3rd intermediate period' 1]
#  ['neo-rococo' 2]
#  ['expressionism, native art' 2]
#  ['romanticism, realism' 2]
#  ['metaphysical art, surrealism' 2]
#  ['neoclassicism, surrealism' 2]
#  ['academicism, romanticism' 2]
#  ['realism, impressionism' 2]
#  ['ink and wash painting' 2]
#  ['neoclassicism, romanticism' 2]
#  ['realism, social realism' 2]
#  ['naturalism' 2]
#  ['neoclassicism, academicism' 2]
#  ['new european painting' 2]
#  ['luminism' 2]
#  ['verism' 2]
#  ['safavid period' 2]
#  ['expressionism, fauvism' 2]
#  ['naïve art (primitivism), surrealism' 2]
#  ['art nouveau (modern), post-impressionism' 2]
#  ['mannerism (late renaissance), baroque' 3]
#  ['biedermeier' 3]
#  ['japonism, post-impressionism' 3]
#  ['impressionism, realism' 3]
#  ['figurative expressionism, expressionism' 3]
#  ['neoclassicism, baroque' 3]
#  ['conceptual art, pop art' 3]
#  ['photorealism, pop art' 3]
#  ['expressionism, symbolism' 4]
#  ['gothic' 4]
#  ['ukiyo-e' 4]
#  ['academicism, realism' 4]
#  ['expressionism, figurative expressionism' 4]
#  ['pointillism' 4]
#  ['neoclassicism, orientalism' 4]
#  ['neo-impressionism' 5]
#  ['analytical\xa0realism' 5]
#  ['contemporary realism' 5]
#  ['neo-baroque' 5]
#  ['postcolonial art, magic realism' 5]
#  ['tonalism' 6]
#  ['american realism' 6]
#  ['kitsch' 6]
#  ['high renaissance, mannerism (late renaissance)' 6]
#  ['precisionism' 6]
#  ['metaphysical art' 6]
#  ['japonism' 7]
#  ['international gothic, proto renaissance' 7]
#  ['post-impressionism, neo-impressionism' 7]
#  ['orientalism' 7]
#  ['divisionism, neo-impressionism' 8]
#  ['art deco' 8]
#  ['neo-figurative art, new realism' 9]
#  ['byzantine' 9]
#  ['figurative expressionism' 10]
#  ['neo-expressionism' 10]
#  ['renaissance' 10]
#  ['fauvism' 11]
#  ['muralism' 11]
#  ['social realism' 11]
#  ['neo-figurative art' 11]
#  ['mannerism (late renaissance), renaissance' 12]
#  ['neo-romanticism' 12]
#  ['romanticism, orientalism' 12]
#  ['regionalism' 15]
#  ['new realism' 16]
#  ['pointillism, neo-impressionism' 16]
#  ['mosan art' 20]
#  ['pop art' 21]
#  ['cloisonnism' 23]
#  ['academicism' 28]
#  ['magic realism' 32]
#  ['international gothic' 43]
#  ['surrealism' 44]
#  ['naïve art (primitivism)' 46]
#  ['tenebrism' 50]
#  ['symbolism' 51]
#  ['art nouveau (modern)' 62]
#  ['classicism' 105]
#  ['expressionism' 123]
#  ['baroque, tenebrism' 125]
#  ['neoclassicism' 128]
#  ['proto renaissance' 191]
#  ['post-impressionism' 201]
#  ['realism' 260]
#  ['impressionism' 347]
#  ['romanticism' 353]
#  ['rococo' 355]
#  ['high renaissance' 467]
#  ['northern renaissance' 546]
#  ['mannerism (late renaissance)' 689]
#  ['early renaissance' 791]
#  ['baroque' 1188]
#  [None 11768]]

# %% [markdown]
# ### 4. Description length

# %%
data_description_word_count = data.with_columns(
    pl.col("description")
    .map_elements(lambda x: len(x.split(" ")), return_dtype=pl.Int64)
    .alias("description word count")
)

fig = px.box(
    data_description_word_count,
    x="description word count",
    title="Description Word Count",
    color_discrete_sequence=COLORS[0:3],
    color="source"
)
fig.update_xaxes(title_text="number of words")
fig.show()

# %%
description_lengths = ["shortest:\n", "\nmedium:\n", "\nlong:\n"]

for index, description_index in enumerate([0, 5000, 10000]):
    description = data_description_word_count.sort("description word count")["description"][
        description_index
    ]

    print(f"{description_lengths[index]}{description}")
# Out:
# shortest:
# Mastelletta's grand, open-air fêtes champêtres, combining landscape and slender, silhouette-like figures, depicted through a simplified, expressionistic design, lie at the root of his fame and originality.
#
# medium:
# The only work by Antonello still in Venice, where he resided in 1475 and 1476, it was probably painted at the beginning of his stay in the city. The splendid background scene, one of the best preserved parts of this very badly damaged painting, with the apse of the church of San Francesco d'Assisi in Messina, is the artist's tribute to the city of his birth.
#
# long:
# In addition to those in the central section of the ceiling of the main hall, four other virtues appear inside stucco frames on the walls of the room: Marital Harmony, Humility Casting Out Pride, Liberality Dispensing Gifts, and Virtue Crowning Honour.
# In the Marital Harmony, the beautiful young woman is comfortably seated on a chair, the man is standing, leaning toward her and holding a heart on a chain. The scene seems to come out of an eighteenth-century melodrama, with the official lover of a married woman paying homage to his lady, while a little white dog is cuddled by a winged cupid, a clear symbol of fidelity.
